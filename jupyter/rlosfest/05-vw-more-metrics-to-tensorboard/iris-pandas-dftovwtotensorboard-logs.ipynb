# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from vowpalwabbit import pyvw
from vowpalwabbit.DFtoVW import (
    DFtoVW,
    Feature,
    MulticlassLabel,
    SimpleLabel
)
# import tensorboardX as tx
# from datetime import datetime
from vowpalwabbit.DFtoVWtoTensorboard import VWtoTensorboard, DFtoVWtoTensorboard

# %%
df = pd.read_csv('./Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# converting "Species" categorical column to integer
def categorical_to_int(specie):
    if specie == 'Iris-setosa':
        return 1
    elif specie == 'Iris-versicolor':
        return 2
    elif specie == 'Iris-virginica':
        return 3
    
df['Species'] = df['Species'].apply(categorical_to_int)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
# Splitting train test
train, test = train_test_split(df, test_size=0.1)

# %%
print("Length of test:", len(train))
test
# Out:
# Length of test: 135
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 126  127            6.2           2.8            4.8           1.8        3
# 117  118            7.7           3.8            6.7           2.2        3
# 76    77            6.8           2.8            4.8           1.4        2
# 70    71            5.9           3.2            4.8           1.8        2
# 79    80            5.7           2.6            3.5           1.0        2
# 45    46            4.8           3.0            1.4           0.3        1
# 97    98            6.2           2.9            4.3           1.3        2
# 61    62            5.9           3.0            4.2           1.5        2
# 58    59            6.6           2.9            4.6           1.3        2
# 80    81            5.5           2.4            3.8           1.1        2
# 19    20            5.1           3.8            1.5           0.3        1
# 128  129            6.4           2.8            5.6           2.1        3
# 143  144            6.8           3.2            5.9           2.3        3
# 134  135            6.1           2.6            5.6           1.4        3
# 83    84            6.0           2.7            5.1           1.6        2

# %%
print("Length of test:", len(test))
test
# Out:
# Length of test: 15
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 126  127            6.2           2.8            4.8           1.8        3
# 117  118            7.7           3.8            6.7           2.2        3
# 76    77            6.8           2.8            4.8           1.4        2
# 70    71            5.9           3.2            4.8           1.8        2
# 79    80            5.7           2.6            3.5           1.0        2
# 45    46            4.8           3.0            1.4           0.3        1
# 97    98            6.2           2.9            4.3           1.3        2
# 61    62            5.9           3.0            4.2           1.5        2
# 58    59            6.6           2.9            4.6           1.3        2
# 80    81            5.5           2.4            3.8           1.1        2
# 19    20            5.1           3.8            1.5           0.3        1
# 128  129            6.4           2.8            5.6           2.1        3
# 143  144            6.8           3.2            5.9           2.3        3
# 134  135            6.1           2.6            5.6           1.4        3
# 83    84            6.0           2.7            5.1           1.6        2

# %%
target_col = "Species"

# features = [Feature(col) for col in df.columns if col != target_col]  # target column not part of Features
features = [Feature(col) for col in df.columns if col != target_col and col != 'Id']  # 'Id' column also not part of Features along with target col
label = MulticlassLabel(label=target_col)  # target column is a multi class label column
tag = 'Id'

df_to_vw = DFtoVW(df=df, features=features, label=label, tag=tag)

# %%
vw = pyvw.vw('--oaa 3 -P 1')  # -oaa is One Agent All algo for multi class problem (seems supervised) -P 1 outputs metrics for each example

# %%
# Before running this run command `rm -rf ./logs` in this directory to remove any previous logs for tensorboard
logdir = 'logs/scalars'
vw_to_tb = VWtoTensorboard(logdir)

df_to_tb = DFtoVWtoTensorboard(df_to_vw, vw)
df_to_tb.fit(train, vw_to_tb)  # If VWtoTensorboard object passed as parameter then run in the current directory command `tensorboard --logdir ./logs`
# Out:
# average_loss:0.039735	since_last:0.039735	label: 1	prediction: 3	num_features: 5
# average_loss:0.046053	since_last:1.000000	label: 1	prediction: 3	num_features: 5
# average_loss:0.052288	since_last:1.000000	label: 1	prediction: 3	num_features: 5
# average_loss:0.051948	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.051613	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.051282	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.050955	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.050633	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.050314	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.050000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.049689	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.049383	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.049080	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.048780	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.048485	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.048193	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.047904	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.047619	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.047337	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.047059	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.046784	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.046512	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.046243	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.045977	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.045714	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.045455	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.045198	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.044944	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.044693	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.044444	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.044199	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.043956	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.043716	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.043478	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.043243	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.043011	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.042781	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.042553	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.042328	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.042105	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.041885	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.041667	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.041451	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.041237	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.041026	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.040816	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.040609	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.040404	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.040201	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.040000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.044776	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.049505	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.054187	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.058824	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.058537	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.058252	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.057971	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.057692	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.057416	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.057143	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.056872	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.056604	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.056338	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.056075	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.055814	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.055556	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.055300	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.055046	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.054795	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.054545	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.054299	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.054054	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.053812	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.053571	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.053333	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.053097	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.052863	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.052632	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.052402	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.052174	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051948	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051724	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051502	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051282	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051064	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.050847	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.050633	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.050420	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.050209	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.050000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.049793	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.049587	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.049383	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.049180	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048980	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048780	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048583	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048387	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048193	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.048000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.051793	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.055556	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.059289	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.062992	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.062745	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.062500	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.062257	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.062016	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.061776	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.061538	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.061303	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.061069	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.060837	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.060606	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.060377	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.060150	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.059925	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.059701	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.059480	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.059259	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.059041	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.058824	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.058608	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.058394	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.058182	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.057971	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.057762	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.057554	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.057348	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.057143	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.056940	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.056738	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.056537	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.056338	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.056140	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.055944	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.055749	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.055556	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.055363	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.055172	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054983	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054795	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054608	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054422	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054237	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.054054	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.053872	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.053691	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.053512	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.053333	since_last:0.000000	label: 3	prediction: 3	num_features: 5

# %%
df_simple = pd.DataFrame({
        "f1": [1, 2, 3],
        "f2": [1.2, 2.3, 3.4],
        "f3": [0.2, 0.8, .01],
        "l": [1, 2, 3],
})

label = MulticlassLabel(label="l")
features = [Feature(col) for col in ["f1", "f2", "f3"]]

df_to_vw = DFtoVW(df=df_simple, label=label, features=features)
vw = pyvw.vw('--oaa 3 -P 1')

df_to_tb = DFtoVWtoTensorboard(df_to_vw, vw)
df_to_tb.fit(df_simple)
# Out:
# average_loss:0.000000	since_last:0.000000	label: 1	prediction: 1	num_features: 4
# average_loss:0.500000	since_last:1.000000	label: 2	prediction: 1	num_features: 4
# average_loss:0.666667	since_last:1.000000	label: 3	prediction: 2	num_features: 4

# %%
for i, x in zip(df_simple.index, range(len(df_simple))):
    print(i, x)
# Out:
# 0 0
# 1 1
# 2 2
