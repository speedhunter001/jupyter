# %%
import cv2
import numpy as np
image = cv2.imread('scene.jpg',0)
#image = cv2.imread('catface.jpg',1)
#cv2.namedWindow('f',cv2.WINDOW_NORMAL)

ret, mask = cv2.threshold(image, 250, 255, cv2.THRESH_BINARY)

#image = cv2.imread('bleedclassical/Media/M9/contourconvex.PNG')
#image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

#cv2.rectangle(image, (170, 50), (300, 200), (255, 0, 255), thickness=5, lineType=cv2.LINE_8);
kernel = np.ones((5,5),np.uint8)
#image= cv2.rectangle(image, (170, 50,300, 200), (255, 0, 255), thickness=5, lineType=cv2.LINE_8,shift=2);

mask = cv2.dilate(mask,None)
#image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel,iterations = 1)

#cv2.imwrite('roombak.jpg',frame)
#image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#cv2.imwrite('care3.jpg',mask)

cv2.imshow('f',mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cap = cv2.VideoCapture(1,cv2.CAP_DSHOW)
cap = cv2.VideoCapture(1)

# Using the full resolution of my webcam.
cap.set(3,1280)
cap.set(4,960)
# Out:
# C:\Users\hp-pc\Anaconda3\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
sklearn.__version__
# Out:
# '0.21.2'

# %% [markdown]
# ## <font style="color:rgb(134,19,348)">  fsd  </font>

# %% [markdown]
# ## <font style="color:rgb(254,40,180)">  Scaling  </font>

# %%
cap.release()
cv2.destroyAllWindows()

# %%
cv2.EVENT_MOUSEWHEEL

# %%
cv2.bitwise_and(np.array([0,0,0,80],dtype='float'),np.array([0,0,0,100],dtype='float'))
# Out:
# array([[ 0.],
#        [ 0.],
#        [ 0.],
#        [64.]])

# %%
#Test here
import numpy as np
# Out:
# array([20.08553692, 20.08553692])

# %%
plt.figure(figsize=[25,25])
plt.subplot(131);plt.imshow(b[...,::-1]);plt.title("Blue Channel")
plt.subplot(132);plt.imshow(g,cmap='gray');plt.title("Green Channel")

# %%
#Use GPu
net.setPreferableTarget( cv2.dnn.DNN_TARGET_OPENCL)

# %%
# display with ipython
from IPython.display import Image
Image("media/M5/hists.PNG")
Image(url= "https://i.ytimg.com/vi/TdpBRZ0dZhw/maxresdefault.jpg")

# %% [markdown]
# ### <font style="color:rgb(34,169,34)">Thresholding using OpenCV function</font>

# %% [markdown]
# ### <font style="color:rgb(255,165,0)">Thresholding using OpenCV function</font>

# %%
# Code for displaying in real-time in matplotlib
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
fig = plt.figure()
cap = cv2.VideoCapture('chaplin.mp4')
#cap = cv2.VideoCapture(0)
st = time.time()
for i in range(25):

    ret, image = cap.read()


    #display(fig)
    plt.imshow(image[...,::-1])
    
    clear_output(wait = True)
    plt.show()
    #plt.pause(0.001)
    time.sleep(0.001)
    
cap.release()      
time.time()-st
# Out:
# 6.923396110534668

# %%
cv2.line(img,(100,300),(200,50),(255,255,255),10)
cv2.circle(img,(100,63), 55, (0,255,0), -1)
cv2.rectangle(img,(384,0),(510,228),(0,255,0),3)
cv2.putText(img,'Computer Vision',(0,130), cv2.FONT_HERSHEY_COMPLEX, 1, (200,255,155), 2, cv2.LINE_AA)
#cv2.FONT_HERSHEY_COMPLEX

# %%
_,contours, hierarchy = cv2.findContours(edges2,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img, contours, -1, (0,255,0), 3) #draw all contours
cnt = sorted(contours, key=cv2.contourArea)
c = max(contours, key = cv2.contourArea)
x,y,w,h = cv2.boundingRect(cnt)
cv2.contourArea(cnt)

final = np.hstack((frame,bgr))

# %%
#add fps
fps = 0
start_time = time.time()
cv2.putText(image, 'FPS: {:.2f}'.format(fps), (20, 20),fontFace=cv2.FONT_HERSHEY_SIMPLEX,fontScale=0.3,color=(0, 0, 255))
fps= (1.0 / (time.time() - start_time))

# %%
image = cv2.resize(img, (0,0), fx=0.4, fy=0.4)
image = cv2.resize(img, (672, 420))   #width , height
image.shape # height, width
image.shape[::-1][1:]   # this line is the reverse of this line image.shape[:-1]

# %%
edges = cv2.Canny(img,100,300)

# %%
np.clip(value, 0, 255)   # bind some function between some value

# %%
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,5)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,5)

# %%
mask_inv = cv2.bitwise_not(mask)
img1_bg = cv2.bitwise_and(roi,roi,mask = mask)
combined = cv2.add(img1_bg,img2_fg)

# %%
nums[nums > MAX] = MAX
#this is how you get a new conditionalized array
ab= np.array([[1,2], [3, 4], [5, 6]])  
bool_idx = (ab > 2) 
ab =ab[bool_idx]

# %%
gblur = cv2.GaussianBlur(img,(5,5),0)
median = cv2.medianBlur(img,5)
median = cv2.medianBlur(img,5)

# %%
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
dilation = cv2.dilate(img,kernel,iterations = 1)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

# %%
img2[877:1050, 470:628] = roi    # roi = imgmain[y:y+h, x:x+w ]

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(1)

while(True):
    ret, frame = cap.read()
    frame = cv2.flip( frame, 1 ) 
    if ret:
       gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame',frame)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
import cv2

# %%
import time

import cv2
#cv2.namedWindow('img', cv2.WINDOW_NORMAL)

cam = cv2.VideoCapture(1,cv2.CAP_DSHOW)
cam.set(3,1280)
cam.set(4,720)
# turn the autofocus off
#cam.set(cv2.CAP_PROP_AUTOFOCUS, 1)

while (True):
  ret ,frame = cam.read()   
  if ret:
      #frame = cv2.flip( frame, 1 )     # add this
  
      
      cv2.imshow("img",frame)      # Display the resulting frame
      k = cv2.waitKey(1)
      if   k ==ord('a'):  
          break
      if k ==ord('s'):
          cv2.imwrite('highnormal.jpg',frame)
          break
#release capture when all done      
cam.release()
cv2.destroyAllWindows()

# %%
frame.shape
# Out:
# (480, 640, 3)

# %%
cam.set(3, 1080)
cam.set(4, 1080)
# Out:
# True

# %%
ret ,frame = cam.read()

# %%
ret
# Out:
# True

# %%
cam.release()
cv2.destroyAllWindows()

# %%
cam.release()

# %%
cam.get(3)
# Out:
# 1280.0

# %%
import cv2
# Out:
# (480, 640, 3)

# %%
import cv2
cv2.namedWindow('img', cv2.WINDOW_NORMAL)
cv2.namedWindow('img2', cv2.WINDOW_NORMAL)

cam = cv2.VideoCapture(1)      # Capture frame-by-frame
cam1 = cv2.VideoCapture(0)      # Capture frame-by-frame

print(cam.get(cv2.CAP_PROP_FOURCC))
#print(cam.set(3,1080))
#print(cam.set(4,720))
while (True):
  ret ,frame = cam.read()
  ret1 ,frame1 = cam1.read()   

  if not ret and ret1:
        continue
      #frame = cv2.flip( frame, 1 )     # add this  
      
  cv2.imshow("img",frame)      # Display the resulting frame
  cv2.imshow("img2",frame1)      # Display the resulting frame

  k = cv2.waitKey(1)
  if   k ==ord('a'):  
      break

#release capture when all done      
cam.release()
cam1.release()
cv2.destroyAllWindows()
# Out:
# 20.0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-4068d13174a0> in <module>
#      18
#      19   cv2.imshow("img",frame)      # Display the resulting frame
# ---> 20   cv2.imshow("img2",frame1)      # Display the resulting frame
#      21
#      22   k = cv2.waitKey(1)
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:352: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
cam.release()
cam1.release()

cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

# This is how we define our codec
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# Save our video at 20.0 FPS with the defined dimensions, Note my default camera has these dimensions, yours might be different
out = cv2.VideoWriter(r'neuralasample.mp4',fourcc, 10.0, (640,480))

while(True):
    ret, frame = cap.read()
    if not ret:
        break

    # flip the frame vertically for no reason, you can try 1 or -1
    frame = cv2.flip(frame,1)

    # Save this frame
    out.write(frame)

    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
# Release the video writer Object
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d0dcc72ac338> in <module>
#       5
#       6 # This is how we define our codec
# ----> 7 fourcc = cv2.VideoWriter_fourcc(8,4,4,7)
#       8
#       9 # Save our video at 20.0 FPS with the defined dimensions, Note my default camera has these dimensions, yours might be different
#
# TypeError: Expected single character string for argument 'c1'

# %%
cam.release()
cv2.destroyAllWindows()

# %%
#Close window by clicking x
x=cv2.getWindowProperty("Image",0)
if(x<0):
    usecamera=False

# %%
from tkinter import filedialog
from tkinter import Tk

root = Tk()
root.filename =  filedialog.askopenfilename(title = "Select Image")
root.withdraw()
print (root.filename)

# %%
#points finder
import cv2
img = cv2.imread('bellyman.jpg',1)
radius=5

def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),radius,(255,0,0),-1)
        print(x,y)

cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)
cap = cv2.VideoCapture('slow.flv')
ret,img = cap.read()

while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 305 189
# 389 215

# %%
#ccropping applicationda

import cv2
imgo = cv2.imread("trumpface.jpg")
#imgo = cv2.resize(imgo, (0,0), fx=0.2, fy=0.2)
img =imgo.copy()
radius = 5
cropped = False
x1,x2,y1,y2 =0,0,0,0
points=0
def draw_circle(event,x,y,flags,param):

    if event == cv2.EVENT_LBUTTONDBLCLK:
        global points, x1,x2,y1,y2,cropped
        points+=1
        if points  ==1:
            cv2.circle(img,(x,y),radius,(255,0,0),-1)
            print(x,y)
            x1=x
            y1 = y
        elif points == 2:
            cv2.circle(img,(x,y),radius,(255,0,0),-1)
            print(x,y)
            x2=x
        elif points == 3:
            cv2.circle(img,(x,y),radius,(255,0,0),-1)
            print(x,y)
            y2=y    
            cropped=True
           
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
    if cropped:
       crop_img = imgo[y1:y2, x1:x2]
       #print(crop_img.shape)
       cv2.imshow('imagecr',crop_img)       
    cv2.imshow('image',img)
    
    k = cv2.waitKey(1)
    if k & 0xFF == 27:
        break
        
    elif k == ord('s'): 
       cv2.imwrite('tahaface1.jpg',crop_img)
       break 

cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
 
def nothing(x):
    pass
 
cap = cv2.VideoCapture(0)
cv2.namedWindow("Trackbars")
 
cv2.createTrackbar("L - H", "Trackbars", 0, 179, nothing)
cv2.createTrackbar("L - S", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("L - V", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("U - H", "Trackbars", 179, 179, nothing)
cv2.createTrackbar("U - S", "Trackbars", 255, 255, nothing)
cv2.createTrackbar("U - V", "Trackbars", 255, 255, nothing)
 
 
while True:
    _, frame = cap.read()
    frame = cv2.flip( frame, 1 ) 

    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
 
    l_h = cv2.getTrackbarPos("L - H", "Trackbars")
    l_s = cv2.getTrackbarPos("L - S", "Trackbars")
    l_v = cv2.getTrackbarPos("L - V", "Trackbars")
    u_h = cv2.getTrackbarPos("U - H", "Trackbars")
    u_s = cv2.getTrackbarPos("U - S", "Trackbars")
    u_v = cv2.getTrackbarPos("U - V", "Trackbars")
 
    lower_range = np.array([l_h, l_s, l_v])
    upper_range = np.array([u_h, u_s, u_v])
    mask = cv2.inRange(hsv, lower_range, upper_range)
 
    result = cv2.bitwise_and(frame, frame, mask=mask)
 
    #cv2.imshow("frame", frame)
    cv2.imshow("mask", mask)
    cv2.imshow("result", result)
 
    key = cv2.waitKey(1)
    if key == 27:
        break
    if key == ord('s'):
        thearray = [[l_h,l_s,l_v],[u_h, u_s, u_v]]
        print(thearray)
        #np.save('harryval',thearray)  # ([119,103,93])   ([179,255,255])
        #np.save('penval',thearray)  # ([26,80,147])  ([81,255,255])
       # np.save('drumval',thearray) #([150,70,173])   #([179,189,255])
 
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
#The cropper redefined
import cv2 
cap = cv2.VideoCapture(1,cv2.CAP_DSHOW)

while(1):       
    _, frame = cap.read()
    frame = cv2.flip( frame, 1 ) 
    frame = cv2.flip(frame,1)
    cv2.imshow('image1',frame)    
    k = cv2.waitKey(1)
    if k & 0xFF == 27:
        break
        
    elif k == ord('s'): 
       cv2.imwrite('samplemech.jpg', cropped)
       break 

    elif k == ord("c"):
            r = cv2.selectROI(frame)   # r gives cols, rows, width and height in this order           
            cropped =  frame[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
            cv2.imshow('image',cropped)

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-59a9d1a6971b> in <module>
#      19             r = cv2.selectROI(frame)   # r gives cols, rows, width and height in this order
#      20             cropped =  frame[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
# ---> 21             cv2.imshow('image',cropped)
#      22
#      23 cap.release()
#
# error: OpenCV(4.1.2) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
#The Snap camera
import cv2 
cap = cv2.VideoCapture(1,cv2.CAP_DSHOW)

while(1):       
    _, frame = cap.read()
    frame = cv2.flip( frame, 1 ) 
    frame = cv2.flip(frame,1)
    cv2.imshow('image1',frame)    
    k = cv2.waitKey(1)
    if k & 0xFF == 27:
        break
        
    elif k == ord('s'): 
       cv2.imwrite('samplenone.jpg', frame)
       break 

    elif k == ord("c"):
            r = cv2.selectROI(frame)   # r gives cols, rows, width and height in this order           
            cropped =  frame[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
            cv2.imshow('image',cropped)

cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

while(True):
    ret, frame = cap.read()
    #frame = cv2.flip( frame, 1 ) 
    if ret:       
        cv2.imshow('frame',frame)
        
    k = cv2.waitKey(1)
    if  k == 32:
        break
  

cap.release()
cv2.destroyAllWindows()

# %%
#Golden
#for closing the window when the x button is clicked without crashing the program do this:
cv2.namedWindow('image')
while cv2.getWindowProperty('image', 0) >= 0:    #use this instead of the usual while True:
    #this works because this gives -1 whenever you close the defined window

# %%
#Saving live streams
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(r'mysavedmovie1.mp4',fourcc, 20.0, (640,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        
        frame = cv2.flip(frame,1)#try 0

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
cap.release()

# %%
#paint drawing application

import cv2
import numpy as np
drawing= False

cv2.namedWindow('image')
radius =10
x1 =None
x2 =0
y1 =0
y2=0


def draw_circle(event,x,y,flags,param):
    global x1,y1, x2,y2,drawing

    if event == cv2.EVENT_MOUSEMOVE:
        x2= x
        y2= y       

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        x1=None
        
img = np.zeros((512,512,3), np.uint8)
cv2.setMouseCallback('image',draw_circle)

while True:
    if drawing:
        #print(x1)
   
        if x1 is not None:                  
            img = cv2.line(img, (x1,y1),(x2,y2), [255,255,255], 5)
            x1= x2
            y1 = y2
        else:
            x1,y1 =x2,y2
    
    cv2.imshow('image',img)
    k= cv2.waitKey(1)
    if k  == ord('c'):
        img = np.zeros((512,512,3), np.uint8)
     
    elif k & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
# Blob detection
im = cv2.imread('bblobs.png', cv2.IMREAD_GRAYSCALE)
im2= cv2.imread('bblobs.png', 1)
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector_create()

keypoints = detector.detect(im)

im = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)
 
# Mark blobs using image annotation concepts we have studied so far
for k in keypoints:
    x,y = k.pt
    x=int(round(x))
    y=int(round(y))
    # Mark center in BLACK
    cv2.circle(im2,(x,y),5,(0,0,0),-1)
    # Get radius of blob
    diameter = k.size
    radius = int(round(diameter/2))
    # Mark blob in RED
    cv2.circle(im2,(x,y),radius,(0,0,255),2)
    
cv2.imshow('image',im2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Tune Canny on Image

# %%
import cv2
import numpy as np

canny_on_video = False   # if true the tuning is done on the video else its done on the below image
path_of_image = r'C:\Users\hp-pc\ClassicalOfficial\Week 5 files\Media\M4\sword1.png'

def nothing(x):
    pass

apertures = [3,5,7]
cv2.namedWindow('Trackbars', cv2.WINDOW_NORMAL)

cv2.createTrackbar("lower_thresh", "Trackbars", 100, 600, nothing)
cv2.createTrackbar("upper_thresh", "Trackbars", 400, 800, nothing)
cv2.createTrackbar("aperture_index", "Trackbars", 0, 2, nothing)
cv2.createTrackbar("Gaussian_Blurring", "Trackbars", 0, 12, nothing)

if canny_on_video :
    cap = cv2.VideoCapture(0)  

while True: 
    if canny_on_video:
        ret ,frame = cap.read()  
        if not ret:
            break
    else:    
        frame = cv2.imread(path_of_image,1)
        
    frame = cv2.flip( frame, 1 ) 

    lower_thresh =cv2.getTrackbarPos("lower_thresh", "Trackbars")
    upper_thresh = cv2.getTrackbarPos("upper_thresh", "Trackbars")
    aperture_index = cv2.getTrackbarPos("aperture_index", "Trackbars")
    Gaussian_Blurring = cv2.getTrackbarPos("Gaussian_Blurring", "Trackbars")

    # we are making sure that the gaussian kernel is an odd number
    if Gaussian_Blurring > 0:
        frame = cv2.GaussianBlur(frame, (2 * Gaussian_Blurring + 1, 2 * Gaussian_Blurring + 1), 0);
        
    apertureSize = apertures[aperture_index]                
    edges = cv2.Canny(frame, lower_thresh, upper_thresh, apertureSize= apertureSize)   
    cv2.imshow("Trackbars", edges)
 
    key = cv2.waitKey(1)
    if key == 27:
        break
    if key == ord('s'):
        print('lower {}, upper {}, apertureSize {}, blur {}'.format(lower_thresh,upper_thresh,apertureSize,Gaussian_Blurring))
        break
       
if canny_on_video:
    cap.release()    
cv2.destroyAllWindows()

# %% [markdown]
# # PYTHON

# %%
with open('boxes.txt', 'a') as fr:# a means append text this way you can avoid overwriting text. you can use 'w' to write
        fr.write("appended text") # but if you use this way then after you come out of with statement the file is closed
#also remembet that 'rb' and 'wb' are read and wirte binary permissions

# %%
fr = open('boxes.txt', 'a')  # now this way you can close the file whenever you want
for x in range(10):
     fr.write('whatever you want to write here (in append mode) here.\n')
    
fr.close()
# note using the w flag can also create a file if it did not exist before
#'r+'  read + write text
#'w+'  read + write text
#'a+'  append + read text

# %%
fr = open('boxes.txt', 'r')  # now this way you can close the file whenever you want
for x in range(10):
     fr.read('whatever you want to write here (in append mode) here.\n')
    
fr.close()

# %%
f = open('boxes.txt', 'r')
x = f.readlines()  #this reads each line as an element of a list
f.close()
print(type(x))

# %%
list_of_lists= []
with open('boxes2.txt','r') as f:
    for line in f:
        inner_list = [elt.strip() for elt in line.split(',')]
        # in alternative, if you need to use the file content as numbers
        # inner_list = [int(elt.strip()) for elt in line.split(',')]
        list_of_lists.append(inner_list)
print(list_of_lists)

# %%
#A common use case is that of columnar data, but our units of storage are the rows of the file, that we have read one by one,
#so you may want to transpose your list of lists. This can be done with the following idiom
by_cols = list(zip(*list_of_lists))
print(by_cols)

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(1)
cap2 = cv2.VideoCapture(2)


while(True):
    ret, frame = cap.read()
    frame = cv2.flip( frame, 1 )
    ret, frame2 = cap2.read()
    frame2 = cv2.flip( frame2, 1 ) 
  
    
    cv2.imshow('frame',frame)
    cv2.imshow('frame2',frame2)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cap2.release()

cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()
cap.release()
cap2.release()

# %%
import cv2

# %%
print('fsd')
cv2.__version__
# Out:
# fsd
# '4.1.0'

# %%
source1 = cv2.imread('bleedofffical.png',-1)
source1 = cv2.resize(source1, (0,0), fx=0.6, fy=0.6)

mask = source1[:,:,-1]
source = source1[:,:,:3]

center_point = (1282,1282)

# Specify the roi of src image which you want to paste, I'm specifying the full image as white to say I want to paste the whole 
# image  (although a close white filled hull around the helicopter would yeild even better results for normal cloning)
#mask = np.ones(source.shape, dtype='uint8') * 255

# We are doing both type of cloning Normal and Mixed, and we're also doing monochrome transfer
cloned_image_normal = cv2.seamlessClone(source, destination, mask, center_point, cv2.NORMAL_CLONE)
cloned_image_mixed = cv2.seamlessClone(source, destination, mask, center_point, cv2.MIXED_CLONE)
Monochrome = cv2.seamlessClone(source, destination, mask, center_point, cv2.MONOCHROME_TRANSFER)

cv2.imwrite('normal.jpg',cloned_image_normal)
cv2.imwrite('cloned_image_mixed.jpg',cloned_image_normal)
cv2.imwrite('Monochrome.jpg',cloned_image_normal)

# %matplotlib inline
#rows = np.ceil(len(allshapes)/2)
plt.figure(figsize=[30,30])
plt.subplot(311);plt.imshow(cloned_image_normal[:,:,::-1]);plt.title("Normal Cloning");plt.axis('off')
plt.subplot(312);plt.imshow(Monochrome[:,:,::-1]);plt.title("MonoChrome Transfer");plt.axis('off');
plt.subplot(313);plt.imshow(cloned_image_mixed[:,:,::-1]);plt.title("Mixed Cloning");plt.axis('off');

# %%
source.shape
# Out:
# (2500, 2500, 3)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
destination = cv2.imread('bulb.jpg',1)
print(destination.shape)
plt.imshow(destination[:,:,::-1])
# Out:
# (2848, 4288, 3)
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
plt.imshow(mask, cmap='gray')

# %% [markdown]
# ###  <font style="color:rgb(34,169,134)"> Assignment: BASIC MNIST (Number) CLASSIFIER </font>
# So you will build a very basic MNIST (or simple numbers classifier), which will classify images of numbers in 10 classes 0-9 numbers based on shape analysis, just save 10 contours in memory (0-9 numbers) and perform shape comparasion of every image with all 10 images stored in memory.
